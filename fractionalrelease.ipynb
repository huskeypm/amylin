# %% [markdown]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# ### Ran simpleRyR_runner.py to generate Ca dependent activation data
# <code>
# python simpleRyR_runner.py
# </code>
# generates simpleRyR.txt as output

# %%
fileName = "simpleRyR.txt"
data  = np.loadtxt(fileName)
caJcts = data[:,0]
pOMax = data[:,1]
pOAvg = data[:,2]

plt.plot(caJcts*mM_to_uM,pOMax*1e6,label="Po Max") 
plt.plot(caJcts*mM_to_uM,pOAvg*1e6,label="Po Mean") 
plt.legend(loc=0)
plt.ylabel("Po (1e6)")
plt.xlabel("Ca [uM]")

# %% [markdown]
# ## Quick review of SBM model data at different pacing frequencies for control, +amylin incubated, HIP transgenic
# Data taken from https://docs.google.com/spreadsheets/d/1WWbGLlzAKW1pdtvta5J7oTf4Tfn27Ni27zBpe6kl57I/edit#gid=0

# %%
import pandas as pd

# %%
#df = pd.read_csv("Despa.csv")
df = pd.read_csv("data/Despa.csv")

# %%
df
# Out:
#        Case   Hz  SL_Ca_max  SR_Ca_max  SR_Ca_min     RYR_I    RYR_ O  \
# 0   Control  0.1   0.017871   0.712860   0.279400  0.001171  0.000051
# 1   +Amylin  0.1   0.019253   0.730490   0.284930  0.001211  0.000062
# 2       HIP  0.1   0.018787   0.723760   0.244020  0.001202  0.000054
# 3   Control  0.5   0.014009   0.664970   0.295188  0.002555  0.000119
# 4   +Amylin  0.5   0.019178   0.728900   0.285720  0.003581  0.000147
# 5       HIP  0.5   0.015930   0.688830   0.255370  0.002935  0.000128
# 6   Control  1.0   0.011242   0.626330   0.310600  0.003070  0.000162
# 7   +Amylin  1.0   0.018397   0.716550   0.284040  0.005792  0.000231
# 8       HIP  1.0   0.012400   0.642460   0.276400  0.003421  0.000171
# 9   Control  1.5   0.010370   0.615100   0.319522  0.004256  0.000235
# 10  +Amylin  1.5   0.015942   0.690090   0.294070  0.007773  0.000330
# 11      HIP  1.5   0.011060   0.624080   0.290716  0.004453  0.000239
# 12  Control  2.0   0.010188   0.616470   0.327800  0.005031  0.000281
# 13  +Amylin  2.0   0.014513   0.674700   0.306510  0.008300  0.000371
# 14      HIP  2.0   0.010570   0.620541   0.302473  0.005006  0.000278
#
#     Cleft_Ca_max  Cleft_Ca_min  i_CaL_Max  i_CaL_Min  Unnamed: 11
# 0       0.335960      0.000444  -0.000867 -23.822788          NaN
# 1       0.336941      0.000553  -0.000888 -23.242700          NaN
# 2       0.337290      0.000490  -0.000893 -23.649580          NaN
# 3       0.298991      0.000412  -0.000861 -23.678690          NaN
# 4       0.340278      0.000563  -0.000856 -23.013236          NaN
# 5       0.320810      0.000467  -0.000893 -23.613780          NaN
# 6       0.219590      0.000399  -0.000793 -22.851070          NaN
# 7       0.343405      0.000551  -0.000820 -22.806460          NaN
# 8       0.249150      0.000444  -0.000853 -22.941700          NaN
# 9       0.201645      0.000400  -0.000793 -22.668150          NaN
# 10      0.321369      0.000536  -0.000788 -22.248890          NaN
# 11      0.205872      0.000452  -0.000813 -22.461800          NaN
# 12      0.193960      0.000420  -0.000748 -22.635800          NaN
# 13      0.265125      0.000543  -0.000752 -21.907310          NaN
# 14      0.193030      0.000482  -0.000770 -22.476460          NaN

# %%
bools = df['Case'].isin(['Control'])
print df[bools]
print df.columns
# Out:
#        Case   Hz  SL_Ca_max  SR_Ca_max  SR_Ca_min     RYR_I    RYR_ O  \
# 0   Control  0.1   0.017871    0.71286   0.279400  0.001171  0.000051
# 3   Control  0.5   0.014009    0.66497   0.295188  0.002555  0.000119
# 6   Control  1.0   0.011242    0.62633   0.310600  0.003070  0.000162
# 9   Control  1.5   0.010370    0.61510   0.319522  0.004256  0.000235
# 12  Control  2.0   0.010188    0.61647   0.327800  0.005031  0.000281
#
#     Cleft_Ca_max  Cleft_Ca_min  i_CaL_Max  i_CaL_Min  Unnamed: 11
# 0       0.335960      0.000444  -0.000867 -23.822788          NaN
# 3       0.298991      0.000412  -0.000861 -23.678690          NaN
# 6       0.219590      0.000399  -0.000793 -22.851070          NaN
# 9       0.201645      0.000400  -0.000793 -22.668150          NaN
# 12      0.193960      0.000420  -0.000748 -22.635800          NaN
# Index([u'Case', u'Hz', u'SL_Ca_max', u'SR_Ca_max', u'SR_Ca_min', u'RYR_I',
#        u'RYR_ O', u'Cleft_Ca_max', u'Cleft_Ca_min', u'i_CaL_Max', u'i_CaL_Min',
#        u'Unnamed: 11'],
#       dtype='object')

# %% [markdown]
# #### SL Ca max
# Brad reported SL Ca max, but probably the more meaningful statistic will be the cleft or SL [Ca] at diastole. Nevertheless, the peak Ca declines with frequency and we have +amy > +hip > ctl. Note that +hip has reduced SERCA function

# %%
cases = ['Control', '+Amylin', 'HIP']
colors = ['k','b','r']
mM_to_uM=1e3
#data = "SL_Ca_max"; col = 2
data = "Cleft_Ca_min"; col = 8
plt.subplot(2,2,1)
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    
    sl_ca_max = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    plt.plot(hz,mM_to_uM*sl_ca_max,colors[i],label=case)

art = []
lgd = plt.legend(bbox_to_anchor = (3.1,1.1))
art.append(lgd)
plt.title(data)
plt.ylabel("Ca [uM]")
#plt.xlabel("Hz")


#
plt.subplot(2,2,2)
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    data = "SR_Ca_max"; col =3
    dia = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    data = "SR_Ca_min"; col =4
    sys = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    fracRel = (dia - sys)/dia
    plt.plot(hz,fracRel,colors[i],label=case)

plt.ylabel("%")
plt.xlabel("Hz")
plt.title("Fractional release")


# plot 2 
caJctsSub=caJcts[ np.argwhere(caJcts < 10e-3)]
pOMaxSub=pOMax[ np.argwhere(caJcts < 10e-3)]
pOAvgSub=pOAvg[ np.argwhere(caJcts < 10e-3)]
plt.subplot(2,2,4)
plt.plot(caJctsSub*mM_to_uM,pOMaxSub*1e6,label="Po Max") 
plt.plot(caJctsSub*mM_to_uM,pOAvgSub*1e6,label="Po Mean") 


data = "Cleft_Ca_min"; col = 8
for i,case in enumerate(cases):
    bools = df['Case'].isin([case])
    # i know there is a smarter way of doing this....
    vals =df[bools].as_matrix(columns=df.columns[col:(col+1)])
    daVal = vals[2]*mM_to_uM # 1 Hz
    print daVal
    
    # interpolate corresponding pO val 
    #pointerp = np.interp(daVal,caJctsSub*mM_to_uM,pOMaxSub*1e6)
    xp = np.ndarray.flatten(caJctsSub*mM_to_uM)
    fp = np.ndarray.flatten(pOMaxSub*1e6)
    interped= np.interp(daVal, xp, fp)
    plt.scatter(daVal,interped,c=colors[i])
    

plt.legend(loc=0)
plt.ylabel("Po (*1e6)")
plt.xlabel("Ca [uM]")


######
plt.subplot(2,2,3)
data = "SR_Ca_max"; col =3
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    
    entreys = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    plt.plot(hz,entreys,colors[i],label=case)

data = "SR_Ca_min"; col =4
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    
    entreys = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    plt.plot(hz,entreys,colors[i]+'--',label=case)

plt.ylabel("Ca [mM]")
plt.xlabel("Hz")
#plt.title("SR Ca max/min")
########

plt.tight_layout()

plt.gcf().savefig("fractionalrelease.png",additional_artists=art,bbox_inches='tight',dpi=300)
# Out:
# [ 0.399477]
# [ 0.55121]
# [ 0.444]

# %% [markdown]
# #### SR Ca handling
# SR diastolic/systolic content both decline with increasing pacing, which results in reduced fractional release with pacing.
# The +amy and +hip present the largest SR Ca transients and greater fractional release than control.

# %%
cases = ['Control', 'Amy', 'HIP']
colors = ['k','b','r']


plt.subplot(2,2,1)
data = "SR_Ca_max"; col =3
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    
    entreys = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    plt.plot(hz,entreys,colors[i],label=case)
plt.legend(bbox_to_anchor=[2,-0.5])

data = "SR_Ca_min"; col =4
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    
    entreys = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    plt.plot(hz,entreys,colors[i]+'--',label=case)

plt.ylabel("Ca [mM]")
plt.xlabel("Hz")
plt.title("SR Ca max/min")


plt.subplot(2,2,2)
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    data = "SR_Ca_max"; col =3
    dia = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    data = "SR_Ca_min"; col =4
    sys = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    fracRel = (dia - sys)/dia
    plt.plot(hz,fracRel,colors[i],label=case)

plt.ylabel("%")
plt.xlabel("Hz")
plt.title("Fractional release")

plt.subplot(2,2,3)
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    
    data = "SR_Ca_max"; col =3
    dia = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    data = "SR_Ca_min"; col =4
    sys = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    rel = (dia - sys)
    plt.plot(hz,rel,colors[i],label=case)

plt.ylabel("Ca [mM]")
plt.xlabel("Hz")
plt.title("Delta SR Ca")
plt.tight_layout()

# %% [markdown]
# #### RyR open, inactive states
#
# RyR open/inactive states increase with pacing, with +amylin/HIP presenting largest open/inactive states. These are negatively correlated with the increased SR Ca transients shown above with pacing.

# %%
cases = ['Control', 'Amy', 'HIP']
colors = ['k','b','r']

data = "RyR"
for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
    
    data = "RyR_O"; col=6
    z = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    plt.plot(hz,z,colors[i],label=case+", RyR Open")
    data = "RyR_I"; col=5
    z = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    plt.plot(hz,0.1*z,colors[i]+"--",label=case+", RyR I x 0.1")

plt.legend(loc=0)
plt.title(data)

# %%
cases = ['Control', 'Amy', 'HIP']
colors = ['k','b','r']


for i,case in enumerate(cases):
    #bools = df['Case'].isin(['Control'])
    bools = df['Case'].isin([case])
    hz =df[bools].as_matrix(columns=df.columns[1:2])
        
    data = "RyR_O"; col=6    
    ryro = df[bools].as_matrix(columns=df.columns[col:(col+1)])
    data = "SL_Ca"; col = 2
    sl_ca_max = df[bools].as_matrix(columns=df.columns[col:(col+1)])    
    plt.plot(sl_ca_max,ryro,colors[i],label=case)
plt.legend(loc=0)
plt.title("RyR Open probability vs SL Max Ca")
